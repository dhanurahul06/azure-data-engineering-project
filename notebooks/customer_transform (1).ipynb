# %%
df = spark.read.format("csv") \
    .option("header", "true") \
    .option("inferSchema", "true") \
    .load("abfss://landing@rahulde2026lake.dfs.core.windows.net/dbo.Customers.txt")

df.show()
from pyspark.sql.functions import concat, lit

df_with_fullname = df.withColumn("FullName", concat(df["FirstName"], lit(" "), df["LastName"]))
df_with_fullname.show()
# Out:
# +----------+---------+--------+--------------------+---------+-------------------+
# |CustomerID|FirstName|LastName|               Email|     City|         SignupDate|
# +----------+---------+--------+--------------------+---------+-------------------+
# |         1|    Aarav|  Sharma|aarav.sharma@emai...|   Mumbai|2024-01-15 00:00:00|
# |         2|    Priya|    Nair|priya.nair@email.com|Bengaluru|2024-02-20 00:00:00|
# |         3|    Rohan|   Mehta|rohan.mehta@email...|    Delhi|2024-03-05 00:00:00|
# |         4|   Ananya|    Iyer|ananya.iyer@email...|  Chennai|2024-03-22 00:00:00|
# |         5|   Vikram|   Singh|vikram.singh@emai...|     Pune|2024-04-10 00:00:00|
# |         6|    Sneha|   Reddy|sneha.reddy@email...|Hyderabad|2024-05-01 00:00:00|
# |         7|    Karan|   Joshi|karan.joshi@email...|Ahmedabad|2024-05-18 00:00:00|
# |         8|     Diya|  Kapoor|diya.kapoor@email...|  Kolkata|2024-06-02 00:00:00|
# |         9|    Arjun|  Pillai|arjun.pillai@emai...|   Mumbai|2024-06-25 00:00:00|
# |        10|    Meera|     Rao| meera.rao@email.com|Bengaluru|2024-07-08 00:00:00|
# +----------+---------+--------+--------------------+---------+-------------------+
#
# +----------+---------+--------+--------------------+---------+-------------------+------------+
# |CustomerID|FirstName|LastName|               Email|     City|         SignupDate|    FullName|
# +----------+---------+--------+--------------------+---------+-------------------+------------+
# |         1|    Aarav|  Sharma|aarav.sharma@emai...|   Mumbai|2024-01-15 00:00:00|Aarav Sharma|
# |         2|    Priya|    Nair|priya.nair@email.com|Bengaluru|2024-02-20 00:00:00|  Priya Nair|
# |         3|    Rohan|   Mehta|rohan.mehta@email...|    Delhi|2024-03-05 00:00:00| Rohan Mehta|
# |         4|   Ananya|    Iyer|ananya.iyer@email...|  Chennai|2024-03-22 00:00:00| Ananya Iyer|
# |         5|   Vikram|   Singh|vikram.singh@emai...|     Pune|2024-04-10 00:00:00|Vikram Singh|
# |         6|    Sneha|   Reddy|sneha.reddy@email...|Hyderabad|2024-05-01 00:00:00| Sneha Reddy|
# |         7|    Karan|   Joshi|karan.joshi@email...|Ahmedabad|2024-05-18 00:00:00| Karan Joshi|
# |         8|     Diya|  Kapoor|diya.kapoor@email...|  Kolkata|2024-06-02 00:00:00| Diya Kapoor|
# |         9|    Arjun|  Pillai|arjun.pillai@emai...|   Mumbai|2024-06-25 00:00:00|Arjun Pillai|
# |        10|    Meera|     Rao| meera.rao@email.com|Bengaluru|2024-07-08 00:00:00|   Meera Rao|
# +----------+---------+--------+--------------------+---------+-------------------+------------+

# %%
from pyspark.sql.functions import concat, lit

df_with_fullname = df.withColumn("FullName", concat(df["FirstName"], lit(" "), df["LastName"]))
df_with_fullname.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File <command-7747224169722443>, line 3
#       1 from pyspark.sql.functions import concat, lit
# ----> 3 df_with_fullname = df.withColumn("FullName", concat(df["FirstName"], lit(" "), df["LastName"]))
#       4 df_with_fullname.show()
#
# NameError: name 'df' is not defined

# %%
df_with_fullname.write.format("parquet") \
    .mode("overwrite") \
    .save("abfss://landing@rahulde2026lake.dfs.core.windows.net/customer.parquet")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File <command-7747224169722444>, line 1
# ----> 1 df_with_fullname.write.format("parquet") \
#       2     .mode("overwrite") \
#       3     .save("abfss://landing@rahulde2026lake.dfs.core.windows.net/customer.parquet")
#
# NameError: name 'df_with_fullname' is not defined

# %%
files = dbutils.fs.ls("abfss://landing@rahulde2026lake.dfs.core.windows.net/customer.parquet/")
for f in files:
    print(f.path)
# Out:
# abfss://landing@rahulde2026lake.dfs.core.windows.net/customer.parquet/_SUCCESS
# abfss://landing@rahulde2026lake.dfs.core.windows.net/customer.parquet/_committed_3910831678239623452
# abfss://landing@rahulde2026lake.dfs.core.windows.net/customer.parquet/_committed_4343932156015341303
# abfss://landing@rahulde2026lake.dfs.core.windows.net/customer.parquet/_started_3910831678239623452
# abfss://landing@rahulde2026lake.dfs.core.windows.net/customer.parquet/_started_4343932156015341303
# abfss://landing@rahulde2026lake.dfs.core.windows.net/customer.parquet/part-00000-tid-4343932156015341303-df8c9c50-aa9e-432e-8618-529000169c77-147-1.c000.snappy.parquet

# %%
df_parquet = spark.read.format("parquet") \
    .load("abfss://landing@rahulde2026lake.dfs.core.windows.net/customer.parquet")

df_parquet.show()
df_parquet.write.format("csv") \
    .option("header", "true") \
    .mode("overwrite") \
    .save("abfss://landing@rahulde2026lake.dfs.core.windows.net/processed/customer1.csv")
    files = dbutils.fs.ls("abfss://landing@rahulde2026lake.dfs.core.windows.net/processed/customer1.csv/")
for f in files:
    print(f.path)
# Out:
# +----------+---------+--------+--------------------+---------+-------------------+------------+
# |CustomerID|FirstName|LastName|               Email|     City|         SignupDate|    FullName|
# +----------+---------+--------+--------------------+---------+-------------------+------------+
# |         1|    Aarav|  Sharma|aarav.sharma@emai...|   Mumbai|2024-01-15 00:00:00|Aarav Sharma|
# |         2|    Priya|    Nair|priya.nair@email.com|Bengaluru|2024-02-20 00:00:00|  Priya Nair|
# |         3|    Rohan|   Mehta|rohan.mehta@email...|    Delhi|2024-03-05 00:00:00| Rohan Mehta|
# |         4|   Ananya|    Iyer|ananya.iyer@email...|  Chennai|2024-03-22 00:00:00| Ananya Iyer|
# |         5|   Vikram|   Singh|vikram.singh@emai...|     Pune|2024-04-10 00:00:00|Vikram Singh|
# |         6|    Sneha|   Reddy|sneha.reddy@email...|Hyderabad|2024-05-01 00:00:00| Sneha Reddy|
# |         7|    Karan|   Joshi|karan.joshi@email...|Ahmedabad|2024-05-18 00:00:00| Karan Joshi|
# |         8|     Diya|  Kapoor|diya.kapoor@email...|  Kolkata|2024-06-02 00:00:00| Diya Kapoor|
# |         9|    Arjun|  Pillai|arjun.pillai@emai...|   Mumbai|2024-06-25 00:00:00|Arjun Pillai|
# |        10|    Meera|     Rao| meera.rao@email.com|Bengaluru|2024-07-08 00:00:00|   Meera Rao|
# +----------+---------+--------+--------------------+---------+-------------------+------------+
#
# abfss://landing@rahulde2026lake.dfs.core.windows.net/processed/customer1.csv/_SUCCESS
# abfss://landing@rahulde2026lake.dfs.core.windows.net/processed/customer1.csv/_committed_2771897291766973096
# abfss://landing@rahulde2026lake.dfs.core.windows.net/processed/customer1.csv/_committed_8829021336527114759
# abfss://landing@rahulde2026lake.dfs.core.windows.net/processed/customer1.csv/_started_2771897291766973096
# abfss://landing@rahulde2026lake.dfs.core.windows.net/processed/customer1.csv/_started_8829021336527114759
# abfss://landing@rahulde2026lake.dfs.core.windows.net/processed/customer1.csv/part-00000-tid-8829021336527114759-6c18f222-e05b-4b0b-a609-e3d2ae365877-173-1-c000.csv
